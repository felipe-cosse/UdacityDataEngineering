# %% [markdown]
# # Exercise 02 -  OLAP Cubes - Grouping Sets

# %% [markdown]
# All the databases table in this demo are based on public database samples and transformations
# - `Sakila` is a sample database created by `MySql` [Link](https://dev.mysql.com/doc/sakila/en/sakila-structure.html)
# - The postgresql version of it is called `Pagila` [Link](https://github.com/devrimgunduz/pagila)
# - The facts and dimension tables design is based on O'Reilly's public dimensional modelling tutorial schema [Link](http://archive.oreilly.com/oreillyschool/courses/dba3/index.html)
#
# Start by connecting to the database by running the cells below. If you are coming back to this exercise, then uncomment and run the first cell to recreate the database. If you recently completed the slicing and dicing exercise, then skip to the second cell.

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila_star
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila_star -f Data/pagila-star.sql

# %% [markdown]
# ### Connect to the local database where Pagila is loaded

# %%
import sql
# %load_ext sql

DB_ENDPOINT = "127.0.0.1"
DB = 'pagila_star'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# %sql $conn_string
# Out:
# postgresql://student:student@127.0.0.1:5432/pagila_star
# 'Connected: student@pagila_star'

# %% [markdown]
# ### Star Schema

# %% [markdown]
# <img src="pagila-star.png" width="50%"/>

# %% [markdown]
# # Grouping Sets
# - It happens often that for 3 dimensions, you want to aggregate a fact:
#     - by nothing (total)
#     - then by the 1st dimension
#     - then by the 2nd
#     - then by the 3rd
#     - then by the 1st and 2nd
#     - then by the 2nd and 3rd
#     - then by the 1st and 3rd
#     - then by the 1st and 2nd and 3rd
#
# - Since this is very common, and in all cases, we are iterating through all the fact table anyhow, there is a more clever way to do that using the SQL grouping statement "GROUPING SETS"

# %% [markdown]
# ## Total Revenue
#
# TODO: Write a query that calculates total revenue (sales_amount)

# %%
# %%sql
# SELECT sum(sales_amount)
# FROM factSales
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 1 rows affected.
# [(Decimal('67416.51'),)]

# %% [markdown]
# ## Revenue by Country
# TODO: Write a query that calculates total revenue (sales_amount) by country

# %%
# %%sql
# SELECT sum(sales_amount), dc.country
# FROM factSales fs
#     JOIN dimCustomer dc ON(fs.customer_key = dc.customer_key)
# GROUP BY dc.country
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 108 rows affected.
# [(Decimal('191.47'), 'Cambodia'),
#  (Decimal('1662.12'), 'Turkey'),
#  (Decimal('831.04'), 'Germany'),
#  (Decimal('135.68'), 'Chad'),
#  (Decimal('93.78'), 'Madagascar'),
#  (Decimal('374.04'), 'France'),
#  (Decimal('111.73'), 'Iraq'),
#  (Decimal('709.41'), 'Colombia'),
#  (Decimal('3471.74'), 'Japan'),
#  (Decimal('71.80'), 'American Samoa'),
#  (Decimal('122.68'), 'Virgin Islands, U.S.'),
#  (Decimal('746.28'), 'Vietnam'),
#  (Decimal('111.74'), 'Kuwait'),
#  (Decimal('390.13'), 'Ecuador'),
#  (Decimal('116.78'), 'Nepal'),
#  (Decimal('200.46'), 'Cameroon'),
#  (Decimal('523.79'), 'Saudi Arabia'),
#  (Decimal('402.05'), 'Bangladesh'),
#  (Decimal('73.76'), 'Lithuania'),
#  (Decimal('586.66'), 'Netherlands'),
#  (Decimal('259.43'), 'Yugoslavia'),
#  (Decimal('129.70'), 'Gambia'),
#  (Decimal('1511.48'), 'Nigeria'),
#  (Decimal('318.23'), 'Dominican Republic'),
#  (Decimal('114.72'), 'Faroe Islands'),
#  (Decimal('694.39'), 'Egypt'),
#  (Decimal('134.67'), 'Zambia'),
#  (Decimal('4110.32'), 'United States'),
#  (Decimal('1434.48'), 'Argentina'),
#  (Decimal('89.74'), 'Slovakia'),
#  (Decimal('215.48'), 'Angola'),
#  (Decimal('3045.87'), 'Russian Federation'),
#  (Decimal('187.50'), 'Oman'),
#  (Decimal('136.73'), 'Turkmenistan'),
#  (Decimal('67.82'), 'Afghanistan'),
#  (Decimal('133.71'), 'Czech Republic'),
#  (Decimal('114.72'), 'Liechtenstein'),
#  (Decimal('91.77'), 'Ethiopia'),
#  (Decimal('245.43'), 'Azerbaijan'),
#  (Decimal('3200.52'), 'Brazil'),
#  (Decimal('422.01'), 'Israel'),
#  (Decimal('100.75'), 'Senegal'),
#  (Decimal('328.29'), 'Chile'),
#  (Decimal('92.76'), 'New Zealand'),
#  (Decimal('111.71'), 'Hungary'),
#  (Decimal('344.20'), 'Mozambique'),
#  (Decimal('3307.04'), 'Mexico'),
#  (Decimal('101.74'), 'Finland'),
#  (Decimal('1210.94'), 'Taiwan'),
#  (Decimal('116.70'), 'Sri Lanka'),
#  (Decimal('419.04'), 'Thailand'),
#  (Decimal('115.70'), 'Estonia'),
#  (Decimal('262.40'), 'Latvia'),
#  (Decimal('683.30'), 'Venezuela'),
#  (Decimal('468.88'), 'Peru'),
#  (Decimal('152.66'), 'Holy See (Vatican City State)'),
#  (Decimal('216.54'), 'Runion'),
#  (Decimal('106.65'), 'Anguilla'),
#  (Decimal('112.75'), 'Bahrain'),
#  (Decimal('383.10'), 'Algeria'),
#  (Decimal('369.15'), 'Malaysia'),
#  (Decimal('950.75'), 'Iran'),
#  (Decimal('606.58'), 'Spain'),
#  (Decimal('730.42'), 'Ukraine'),
#  (Decimal('73.82'), 'Tonga'),
#  (Decimal('574.65'), 'South Korea'),
#  (Decimal('277.34'), 'Belarus'),
#  (Decimal('103.78'), 'French Guiana'),
#  (Decimal('142.70'), 'Hong Kong'),
#  (Decimal('123.72'), 'Malawi'),
#  (Decimal('148.69'), 'Nauru'),
#  (Decimal('235.38'), 'Romania'),
#  (Decimal('113.69'), 'North Korea'),
#  (Decimal('254.39'), 'Puerto Rico'),
#  (Decimal('593.63'), 'Canada'),
#  (Decimal('5802.73'), 'China'),
#  (Decimal('307.22'), 'Austria'),
#  (Decimal('127.66'), 'Moldova'),
#  (Decimal('1204.15'), 'South Africa'),
#  (Decimal('253.46'), 'Kenya'),
#  (Decimal('877.97'), 'Poland'),
#  (Decimal('198.48'), 'Kazakstan'),
#  (Decimal('924.80'), 'United Kingdom'),
#  (Decimal('113.65'), 'Brunei'),
#  (Decimal('78.77'), 'Tunisia'),
#  (Decimal('831.11'), 'Italy'),
#  (Decimal('525.72'), 'Pakistan'),
#  (Decimal('144.66'), 'Sweden'),
#  (Decimal('118.75'), 'Armenia'),
#  (Decimal('232.46'), 'Greece'),
#  (Decimal('6630.27'), 'India'),
#  (Decimal('510.83'), 'Yemen'),
#  (Decimal('275.38'), 'Paraguay'),
#  (Decimal('194.48'), 'Myanmar'),
#  (Decimal('2381.32'), 'Philippines'),
#  (Decimal('307.29'), 'Morocco'),
#  (Decimal('137.66'), 'Greenland'),
#  (Decimal('252.39'), 'Switzerland'),
#  (Decimal('1510.33'), 'Indonesia'),
#  (Decimal('120.74'), 'Tuvalu'),
#  (Decimal('96.75'), 'Saint Vincent and the Grenadines'),
#  (Decimal('183.53'), 'Bolivia'),
#  (Decimal('212.50'), 'Congo, The Democratic Republic of the'),
#  (Decimal('227.46'), 'Sudan'),
#  (Decimal('333.16'), 'United Arab Emirates'),
#  (Decimal('341.17'), 'Tanzania'),
#  (Decimal('235.46'), 'French Polynesia'),
#  (Decimal('204.50'), 'Bulgaria')]

# %% [markdown]
# ## Revenue by Month
# TODO: Write a query that calculates total revenue (sales_amount) by month

# %%
# %%sql
# SELECT sum(sales_amount), dc.month
# FROM factSales fs
#     JOIN dimDate dc ON(fs.data_key = dc.date_key)
# GROUP BY dc.month
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 5 rows affected.
# [(Decimal('57118.92'), 4),
#  (Decimal('1028.36'), 5),
#  (Decimal('9648.86'), 1),
#  (Decimal('19263.76'), 2),
#  (Decimal('47773.12'), 3)]

# %% [markdown]
# ## Revenue by Month & Country
# TODO: Write a query that calculates total revenue (sales_amount) by month and country. Sort the data by month, country, and revenue in descending order. The first few rows of your output should match the table below.

# %%
# %%sql
# SELECT sum(sales_amount) as revenue, dd.month, dc.country
# FROM factSales fs
#     JOIN dimDate dd ON(fs.data_key = dd.date_key)
#     JOIN dimCustomer dc ON(fs.customer_key = dc.customer_key)
# GROUP BY dd.month, dc.country
# ORDER BY dd.month, dc.country, revenue desc
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 484 rows affected.
# [(Decimal('67.84'), 1, 'Algeria'),
#  (Decimal('55.86'), 1, 'Angola'),
#  (Decimal('13.94'), 1, 'Anguilla'),
#  (Decimal('163.56'), 1, 'Argentina'),
#  (Decimal('45.84'), 1, 'Austria'),
#  (Decimal('41.94'), 1, 'Azerbaijan'),
#  (Decimal('7.98'), 1, 'Bahrain'),
#  (Decimal('39.90'), 1, 'Bangladesh'),
#  (Decimal('11.96'), 1, 'Belarus'),
#  (Decimal('9.94'), 1, 'Bolivia'),
#  (Decimal('421.00'), 1, 'Brazil'),
#  (Decimal('11.98'), 1, 'Brunei'),
#  (Decimal('19.96'), 1, 'Bulgaria'),
#  (Decimal('23.92'), 1, 'Cambodia'),
#  (Decimal('27.94'), 1, 'Cameroon'),
#  (Decimal('67.86'), 1, 'Canada'),
#  (Decimal('25.92'), 1, 'Chad'),
#  (Decimal('49.90'), 1, 'Chile'),
#  (Decimal('911.82'), 1, 'China'),
#  (Decimal('95.74'), 1, 'Colombia'),
#  (Decimal('87.84'), 1, 'Congo, The Democratic Republic of the'),
#  (Decimal('1.98'), 1, 'Czech Republic'),
#  (Decimal('27.94'), 1, 'Dominican Republic'),
#  (Decimal('41.90'), 1, 'Ecuador'),
#  (Decimal('69.82'), 1, 'Egypt'),
#  (Decimal('19.96'), 1, 'Estonia'),
#  (Decimal('13.98'), 1, 'Faroe Islands'),
#  (Decimal('7.98'), 1, 'Finland'),
#  (Decimal('79.84'), 1, 'France'),
#  (Decimal('11.96'), 1, 'French Guiana'),
#  (Decimal('59.88'), 1, 'French Polynesia'),
#  (Decimal('29.94'), 1, 'Gambia'),
#  (Decimal('179.60'), 1, 'Germany'),
#  (Decimal('55.84'), 1, 'Greece'),
#  (Decimal('35.88'), 1, 'Greenland'),
#  (Decimal('11.96'), 1, 'Holy See (Vatican City State)'),
#  (Decimal('859.78'), 1, 'India'),
#  (Decimal('271.38'), 1, 'Indonesia'),
#  (Decimal('111.68'), 1, 'Iran'),
#  (Decimal('79.78'), 1, 'Israel'),
#  (Decimal('103.78'), 1, 'Italy'),
#  (Decimal('576.70'), 1, 'Japan'),
#  (Decimal('11.94'), 1, 'Kazakstan'),
#  (Decimal('15.94'), 1, 'Kenya'),
#  (Decimal('9.98'), 1, 'Kuwait'),
#  (Decimal('25.94'), 1, 'Latvia'),
#  (Decimal('29.96'), 1, 'Liechtenstein'),
#  (Decimal('19.96'), 1, 'Lithuania'),
#  (Decimal('1.98'), 1, 'Madagascar'),
#  (Decimal('3.98'), 1, 'Malawi'),
#  (Decimal('61.88'), 1, 'Malaysia'),
#  (Decimal('526.74'), 1, 'Mexico'),
#  (Decimal('65.88'), 1, 'Morocco'),
#  (Decimal('57.90'), 1, 'Mozambique'),
#  (Decimal('29.90'), 1, 'Myanmar'),
#  (Decimal('9.98'), 1, 'Nauru'),
#  (Decimal('31.94'), 1, 'Nepal'),
#  (Decimal('51.88'), 1, 'Netherlands'),
#  (Decimal('13.98'), 1, 'New Zealand'),
#  (Decimal('269.42'), 1, 'Nigeria'),
#  (Decimal('11.96'), 1, 'North Korea'),
#  (Decimal('51.88'), 1, 'Oman'),
#  (Decimal('103.76'), 1, 'Pakistan'),
#  (Decimal('3.96'), 1, 'Paraguay'),
#  (Decimal('81.82'), 1, 'Peru'),
#  (Decimal('323.24'), 1, 'Philippines'),
#  (Decimal('109.78'), 1, 'Poland'),
#  (Decimal('31.90'), 1, 'Puerto Rico'),
#  (Decimal('33.92'), 1, 'Romania'),
#  (Decimal('9.98'), 1, 'Runion'),
#  (Decimal('450.80'), 1, 'Russian Federation'),
#  (Decimal('31.94'), 1, 'Saint Vincent and the Grenadines'),
#  (Decimal('131.74'), 1, 'Saudi Arabia'),
#  (Decimal('9.98'), 1, 'Senegal'),
#  (Decimal('17.94'), 1, 'Slovakia'),
#  (Decimal('199.52'), 1, 'South Africa'),
#  (Decimal('93.76'), 1, 'South Korea'),
#  (Decimal('113.70'), 1, 'Spain'),
#  (Decimal('25.94'), 1, 'Sri Lanka'),
#  (Decimal('49.90'), 1, 'Sudan'),
#  (Decimal('9.98'), 1, 'Sweden'),
#  (Decimal('7.96'), 1, 'Switzerland'),
#  (Decimal('111.68'), 1, 'Taiwan'),
#  (Decimal('37.90'), 1, 'Tanzania'),
#  (Decimal('35.92'), 1, 'Thailand'),
#  (Decimal('17.96'), 1, 'Tonga'),
#  (Decimal('241.46'), 1, 'Turkey'),
#  (Decimal('19.98'), 1, 'Turkmenistan'),
#  (Decimal('53.92'), 1, 'Tuvalu'),
#  (Decimal('109.78'), 1, 'Ukraine'),
#  (Decimal('25.90'), 1, 'United Arab Emirates'),
#  (Decimal('147.68'), 1, 'United Kingdom'),
#  (Decimal('618.60'), 1, 'United States'),
#  (Decimal('49.84'), 1, 'Venezuela'),
#  (Decimal('67.82'), 1, 'Vietnam'),
#  (Decimal('1.98'), 1, 'Virgin Islands, U.S.'),
#  (Decimal('31.88'), 1, 'Yemen'),
#  (Decimal('51.88'), 1, 'Yugoslavia'),
#  (Decimal('25.94'), 1, 'Zambia'),
#  (Decimal('9.94'), 2, 'Afghanistan'),
#  (Decimal('121.76'), 2, 'Algeria'),
#  (Decimal('47.90'), 2, 'American Samoa'),
#  (Decimal('71.84'), 2, 'Angola'),
#  (Decimal('33.90'), 2, 'Anguilla'),
#  (Decimal('438.98'), 2, 'Argentina'),
#  (Decimal('25.96'), 2, 'Armenia'),
#  (Decimal('79.78'), 2, 'Austria'),
#  (Decimal('51.86'), 2, 'Azerbaijan'),
#  (Decimal('61.90'), 2, 'Bahrain'),
#  (Decimal('121.72'), 2, 'Bangladesh'),
#  (Decimal('61.80'), 2, 'Belarus'),
#  (Decimal('87.78'), 2, 'Bolivia'),
#  (Decimal('909.74'), 2, 'Brazil'),
#  (Decimal('25.92'), 2, 'Brunei'),
#  (Decimal('85.78'), 2, 'Bulgaria'),
#  (Decimal('73.80'), 2, 'Cambodia'),
#  (Decimal('67.82'), 2, 'Cameroon'),
#  (Decimal('151.60'), 2, 'Canada'),
#  (Decimal('19.96'), 2, 'Chad'),
#  (Decimal('103.74'), 2, 'Chile'),
#  (Decimal('1678.04'), 2, 'China'),
#  (Decimal('145.66'), 2, 'Colombia'),
#  (Decimal('57.82'), 2, 'Congo, The Democratic Republic of the'),
#  (Decimal('31.94'), 2, 'Czech Republic'),
#  (Decimal('67.82'), 2, 'Dominican Republic'),
#  (Decimal('109.80'), 2, 'Ecuador'),
#  (Decimal('243.46'), 2, 'Egypt'),
#  (Decimal('51.88'), 2, 'Estonia'),
#  (Decimal('35.92'), 2, 'Ethiopia'),
#  (Decimal('21.94'), 2, 'Faroe Islands'),
#  (Decimal('37.92'), 2, 'Finland'),
#  (Decimal('105.64'), 2, 'France'),
#  (Decimal('25.96'), 2, 'French Guiana'),
#  (Decimal('37.90'), 2, 'French Polynesia'),
#  (Decimal('21.96'), 2, 'Gambia'),
#  (Decimal('267.42'), 2, 'Germany'),
#  (Decimal('59.88'), 2, 'Greece'),
#  (Decimal('7.98'), 2, 'Greenland'),
#  (Decimal('83.86'), 2, 'Holy See (Vatican City State)'),
#  (Decimal('75.88'), 2, 'Hong Kong'),
#  (Decimal('49.90'), 2, 'Hungary'),
#  (Decimal('1665.84'), 2, 'India'),
#  (Decimal('478.84'), 2, 'Indonesia'),
#  (Decimal('259.30'), 2, 'Iran'),
#  (Decimal('25.94'), 2, 'Iraq'),
#  (Decimal('107.78'), 2, 'Israel'),
#  (Decimal('243.52'), 2, 'Italy'),
#  (Decimal('977.66'), 2, 'Japan'),
#  (Decimal('67.80'), 2, 'Kazakstan'),
#  (Decimal('117.78'), 2, 'Kenya'),
#  (Decimal('73.84'), 2, 'Kuwait'),
#  (Decimal('97.80'), 2, 'Latvia'),
#  (Decimal('41.90'), 2, 'Liechtenstein'),
#  (Decimal('23.94'), 2, 'Lithuania'),
#  (Decimal('25.94'), 2, 'Madagascar'),
#  (Decimal('27.92'), 2, 'Malawi'),
#  (Decimal('95.76'), 2, 'Malaysia'),
#  (Decimal('1009.66'), 2, 'Mexico'),
#  (Decimal('31.90'), 2, 'Moldova'),
#  (Decimal('83.80'), 2, 'Morocco'),
#  (Decimal('29.90'), 2, 'Mozambique'),
#  (Decimal('95.74'), 2, 'Myanmar'),
#  (Decimal('25.94'), 2, 'Nauru'),
#  (Decimal('13.96'), 2, 'Nepal'),
#  (Decimal('173.66'), 2, 'Netherlands'),
#  (Decimal('27.94'), 2, 'New Zealand'),
#  (Decimal('355.20'), 2, 'Nigeria'),
#  (Decimal('1.98'), 2, 'North Korea'),
#  (Decimal('65.84'), 2, 'Oman'),
#  (Decimal('163.62'), 2, 'Pakistan'),
#  (Decimal('69.80'), 2, 'Paraguay'),
#  (Decimal('143.66'), 2, 'Peru'),
#  (Decimal('718.34'), 2, 'Philippines'),
#  (Decimal('323.32'), 2, 'Poland'),
#  (Decimal('65.84'), 2, 'Puerto Rico'),
#  (Decimal('53.84'), 2, 'Romania'),
#  (Decimal('45.90'), 2, 'Runion'),
#  (Decimal('851.88'), 2, 'Russian Federation'),
#  (Decimal('31.92'), 2, 'Saint Vincent and the Grenadines'),
#  (Decimal('75.82'), 2, 'Saudi Arabia'),
#  (Decimal('51.86'), 2, 'Senegal'),
#  (Decimal('33.92'), 2, 'Slovakia'),
#  (Decimal('355.16'), 2, 'South Africa'),
#  (Decimal('109.68'), 2, 'South Korea'),
#  (Decimal('137.70'), 2, 'Spain'),
#  (Decimal('21.94'), 2, 'Sri Lanka'),
#  (Decimal('55.80'), 2, 'Sudan'),
#  (Decimal('59.86'), 2, 'Sweden'),
#  (Decimal('61.88'), 2, 'Switzerland'),
#  (Decimal('343.20'), 2, 'Taiwan'),
#  (Decimal('69.80'), 2, 'Tanzania'),
#  (Decimal('127.68'), 2, 'Thailand'),
#  (Decimal('19.94'), 2, 'Tonga'),
#  (Decimal('9.98'), 2, 'Tunisia'),
#  (Decimal('412.96'), 2, 'Turkey'),
#  (Decimal('63.86'), 2, 'Turkmenistan'),
#  (Decimal('23.94'), 2, 'Tuvalu'),
#  (Decimal('159.60'), 2, 'Ukraine'),
#  (Decimal('127.66'), 2, 'United Arab Emirates'),
#  (Decimal('365.24'), 2, 'United Kingdom'),
#  (Decimal('1180.96'), 2, 'United States'),
#  (Decimal('281.36'), 2, 'Venezuela'),
#  (Decimal('233.48'), 2, 'Vietnam'),
#  (Decimal('53.86'), 2, 'Virgin Islands, U.S.'),
#  (Decimal('141.64'), 2, 'Yemen'),
#  (Decimal('61.84'), 2, 'Yugoslavia'),
#  (Decimal('35.88'), 2, 'Zambia'),
#  (Decimal('49.86'), 3, 'Afghanistan'),
#  (Decimal('223.44'), 3, 'Algeria'),
#  (Decimal('15.92'), 3, 'American Samoa'),
#  (Decimal('135.66'), 3, 'Angola'),
#  (Decimal('89.74'), 3, 'Anguilla'),
#  (Decimal('911.80'), 3, 'Argentina'),
#  (Decimal('63.86'), 3, 'Armenia'),
#  (Decimal('253.40'), 3, 'Austria'),
#  (Decimal('175.58'), 3, 'Azerbaijan'),
#  (Decimal('35.92'), 3, 'Bahrain'),
#  (Decimal('309.28'), 3, 'Bangladesh'),
#  (Decimal('233.48'), 3, 'Belarus'),
#  (Decimal('135.64'), 3, 'Bolivia'),
#  (Decimal('2212.86'), 3, 'Brazil'),
#  (Decimal('59.80'), 3, 'Brunei'),
#  (Decimal('157.60'), 3, 'Bulgaria'),
#  (Decimal('61.78'), 3, 'Cambodia'),
#  (Decimal('143.60'), 3, 'Cameroon'),
#  (Decimal('518.96'), 3, 'Canada'),
#  (Decimal('127.70'), 3, 'Chad'),
#  (Decimal('299.40'), 3, 'Chile'),
#  (Decimal('4123.88'), 3, 'China'),
#  (Decimal('504.92'), 3, 'Colombia'),
#  (Decimal('189.54'), 3, 'Congo, The Democratic Republic of the'),
#  (Decimal('91.82'), 3, 'Czech Republic'),
#  (Decimal('269.30'), 3, 'Dominican Republic'),
#  (Decimal('295.34'), 3, 'Ecuador'),
#  (Decimal('512.80'), 3, 'Egypt'),
#  (Decimal('103.72'), 3, 'Estonia'),
#  (Decimal('99.78'), 3, 'Ethiopia'),
#  (Decimal('89.78'), 3, 'Faroe Islands'),
#  (Decimal('91.78'), 3, 'Finland'),
#  (Decimal('161.52'), 3, 'France'),
#  (Decimal('93.82'), 3, 'French Guiana'),
#  (Decimal('183.62'), 3, 'French Polynesia'),
#  (Decimal('117.74'), 3, 'Gambia'),
#  (Decimal('532.74'), 3, 'Germany'),
#  (Decimal('165.60'), 3, 'Greece'),
#  (Decimal('113.76'), 3, 'Greenland'),
#  (Decimal('115.76'), 3, 'Holy See (Vatican City State)'),
#  (Decimal('109.76'), 3, 'Hong Kong'),
#  (Decimal('47.84'), 3, 'Hungary'),
#  (Decimal('5094.46'), 3, 'India'),
#  (Decimal('1045.26'), 3, 'Indonesia'),
#  (Decimal('700.44'), 3, 'Iran'),
#  (Decimal('63.82'), 3, 'Iraq'),
#  (Decimal('243.40'), 3, 'Israel'),
#  (Decimal('628.52'), 3, 'Italy'),
#  (Decimal('2506.06'), 3, 'Japan'),
#  (Decimal('123.70'), 3, 'Kazakstan'),
#  (Decimal('171.64'), 3, 'Kenya'),
#  (Decimal('107.74'), 3, 'Kuwait'),
#  (Decimal('141.68'), 3, 'Latvia'),
#  (Decimal('57.88'), 3, 'Liechtenstein'),
#  (Decimal('39.84'), 3, 'Lithuania'),
#  (Decimal('111.76'), 3, 'Madagascar'),
#  (Decimal('101.80'), 3, 'Malawi'),
#  (Decimal('311.34'), 3, 'Malaysia'),
#  (Decimal('2276.22'), 3, 'Mexico'),
#  (Decimal('91.78'), 3, 'Moldova'),
#  (Decimal('253.44'), 3, 'Morocco'),
#  (Decimal('209.48'), 3, 'Mozambique'),
#  (Decimal('193.54'), 3, 'Myanmar'),
#  (Decimal('139.72'), 3, 'Nauru'),
#  (Decimal('85.86'), 3, 'Nepal'),
#  (Decimal('472.92'), 3, 'Netherlands'),
#  (Decimal('71.84'), 3, 'New Zealand'),
#  (Decimal('1085.54'), 3, 'Nigeria'),
#  (Decimal('97.80'), 3, 'North Korea'),
#  (Decimal('85.78'), 3, 'Oman'),
#  (Decimal('417.00'), 3, 'Pakistan'),
#  (Decimal('183.56'), 3, 'Paraguay'),
#  (Decimal('347.22'), 3, 'Peru'),
#  (Decimal('1811.96'), 3, 'Philippines'),
#  (Decimal('544.60'), 3, 'Poland'),
#  (Decimal('139.70'), 3, 'Puerto Rico'),
#  (Decimal('143.62'), 3, 'Romania'),
#  (Decimal('175.64'), 3, 'Runion'),
#  (Decimal('1919.36'), 3, 'Russian Federation'),
#  (Decimal('35.88'), 3, 'Saint Vincent and the Grenadines'),
#  (Decimal('359.08'), 3, 'Saudi Arabia'),
#  (Decimal('89.80'), 3, 'Senegal'),
#  (Decimal('41.86'), 3, 'Slovakia'),
#  (Decimal('907.96'), 3, 'South Africa'),
#  (Decimal('355.28'), 3, 'South Korea'),
#  (Decimal('426.98'), 3, 'Spain'),
#  (Decimal('93.76'), 3, 'Sri Lanka'),
#  (Decimal('137.70'), 3, 'Sudan'),
#  (Decimal('97.74'), 3, 'Sweden'),
#  (Decimal('137.62'), 3, 'Switzerland'),
#  (Decimal('797.88'), 3, 'Taiwan'),
#  (Decimal('273.30'), 3, 'Tanzania'),
#  (Decimal('295.36'), 3, 'Thailand'),
#  (Decimal('51.86'), 3, 'Tonga'),
#  (Decimal('33.88'), 3, 'Tunisia'),
#  (Decimal('1163.34'), 3, 'Turkey'),
#  (Decimal('107.84'), 3, 'Turkmenistan'),
#  (Decimal('65.82'), 3, 'Tuvalu'),
#  (Decimal('494.88'), 3, 'Ukraine'),
#  (Decimal('179.54'), 3, 'United Arab Emirates'),
#  (Decimal('552.56'), 3, 'United Kingdom'),
#  (Decimal('3038.90'), 3, 'United States'),
#  (Decimal('438.90'), 3, 'Venezuela'),
#  (Decimal('556.70'), 3, 'Vietnam'),
#  (Decimal('51.88'), 3, 'Virgin Islands, U.S.'),
#  (Decimal('317.30'), 3, 'Yemen'),
#  (Decimal('147.68'), 3, 'Yugoslavia'),
#  (Decimal('95.82'), 3, 'Zambia'),
#  (Decimal('75.84'), 4, 'Afghanistan'),
#  (Decimal('341.20'), 4, 'Algeria'),
#  (Decimal('79.78'), 4, 'American Samoa'),
#  (Decimal('167.60'), 4, 'Angola'),
#  (Decimal('75.72'), 4, 'Anguilla'),
#  (Decimal('1300.80'), 4, 'Argentina'),
#  (Decimal('141.70'), 4, 'Armenia'),
#  (Decimal('235.42'), 4, 'Austria'),
#  (Decimal('219.50'), 4, 'Azerbaijan'),
#  (Decimal('113.72'), 4, 'Bahrain'),
#  (Decimal('327.22'), 4, 'Bangladesh'),
#  (Decimal('241.46'), 4, 'Belarus'),
#  (Decimal('127.72'), 4, 'Bolivia'),
#  (Decimal('2811.58'), 4, 'Brazil'),
#  (Decimal('119.62'), 4, 'Brunei'),
#  (Decimal('143.68'), 4, 'Bulgaria'),
#  (Decimal('203.52'), 4, 'Cambodia'),
#  (Decimal('147.62'), 4, 'Cameroon'),
#  (Decimal('440.88'), 4, 'Canada'),
#  (Decimal('97.78'), 4, 'Chad'),
#  (Decimal('203.54'), 4, 'Chile'),
#  (Decimal('4809.98'), 4, 'China'),
#  (Decimal('642.56'), 4, 'Colombia'),
#  (Decimal('89.80'), 4, 'Congo, The Democratic Republic of the'),
#  (Decimal('141.68'), 4, 'Czech Republic'),
#  (Decimal('271.40'), 4, 'Dominican Republic'),
#  (Decimal('333.22'), 4, 'Ecuador'),
#  (Decimal('562.70'), 4, 'Egypt'),
#  (Decimal('55.84'), 4, 'Estonia'),
#  (Decimal('47.84'), 4, 'Ethiopia'),
#  (Decimal('101.76'), 4, 'Faroe Islands'),
#  (Decimal('65.80'), 4, 'Finland'),
#  (Decimal('399.10'), 4, 'France'),
#  (Decimal('75.82'), 4, 'French Guiana'),
#  (Decimal('171.58'), 4, 'French Polynesia'),
#  (Decimal('89.76'), 4, 'Gambia'),
#  (Decimal('652.42'), 4, 'Germany'),
#  (Decimal('181.62'), 4, 'Greece'),
#  (Decimal('117.70'), 4, 'Greenland'),
#  (Decimal('93.74'), 4, 'Holy See (Vatican City State)'),
#  (Decimal('99.76'), 4, 'Hong Kong'),
#  (Decimal('123.70'), 4, 'Hungary'),
#  (Decimal('5514.92'), 4, 'India'),
#  (Decimal('1213.22'), 4, 'Indonesia'),
#  (Decimal('820.10'), 4, 'Iran'),
#  (Decimal('131.72'), 4, 'Iraq'),
#  (Decimal('407.08'), 4, 'Israel'),
#  (Decimal('678.44'), 4, 'Italy'),
#  (Decimal('2837.24'), 4, 'Japan'),
#  (Decimal('193.52'), 4, 'Kazakstan'),
#  (Decimal('195.58'), 4, 'Kenya'),
#  (Decimal('29.94'), 4, 'Kuwait'),
#  (Decimal('253.40'), 4, 'Latvia'),
#  (Decimal('99.70'), 4, 'Liechtenstein'),
#  (Decimal('53.80'), 4, 'Lithuania'),
#  (Decimal('47.88'), 4, 'Madagascar'),
#  (Decimal('113.74'), 4, 'Malawi'),
#  (Decimal('267.34'), 4, 'Malaysia'),
#  (Decimal('2773.58'), 4, 'Mexico'),
#  (Decimal('131.64'), 4, 'Moldova'),
#  (Decimal('201.48'), 4, 'Morocco'),
#  (Decimal('391.12'), 4, 'Mozambique'),
#  (Decimal('69.78'), 4, 'Myanmar'),
#  (Decimal('121.74'), 4, 'Nauru'),
#  (Decimal('101.80'), 4, 'Nepal'),
#  (Decimal('472.88'), 4, 'Netherlands'),
#  (Decimal('71.76'), 4, 'New Zealand'),
#  (Decimal('1294.86'), 4, 'Nigeria'),
#  (Decimal('115.64'), 4, 'North Korea'),
#  (Decimal('161.52'), 4, 'Oman'),
#  (Decimal('367.06'), 4, 'Pakistan'),
#  (Decimal('293.44'), 4, 'Paraguay'),
#  (Decimal('355.08'), 4, 'Peru'),
#  (Decimal('1857.30'), 4, 'Philippines'),
#  (Decimal('778.24'), 4, 'Poland'),
#  (Decimal('269.36'), 4, 'Puerto Rico'),
#  (Decimal('239.38'), 4, 'Romania'),
#  (Decimal('201.56'), 4, 'Runion'),
#  (Decimal('2853.78'), 4, 'Russian Federation'),
#  (Decimal('93.76'), 4, 'Saint Vincent and the Grenadines'),
#  (Decimal('472.98'), 4, 'Saudi Arabia'),
#  (Decimal('49.86'), 4, 'Senegal'),
#  (Decimal('85.76'), 4, 'Slovakia'),
#  (Decimal('935.68'), 4, 'South Africa'),
#  (Decimal('582.62'), 4, 'South Korea'),
#  (Decimal('514.82'), 4, 'Spain'),
#  (Decimal('91.76'), 4, 'Sri Lanka'),
#  (Decimal('211.52'), 4, 'Sudan'),
#  (Decimal('121.74'), 4, 'Sweden'),
#  (Decimal('281.36'), 4, 'Switzerland'),
#  (Decimal('1131.26'), 4, 'Taiwan'),
#  (Decimal('291.36'), 4, 'Tanzania'),
#  (Decimal('367.16'), 4, 'Thailand'),
#  (Decimal('57.88'), 4, 'Tonga'),
#  (Decimal('111.70'), 4, 'Tunisia'),
#  (Decimal('1484.54'), 4, 'Turkey'),
#  (Decimal('75.80'), 4, 'Turkmenistan'),
#  (Decimal('97.80'), 4, 'Tuvalu'),
#  (Decimal('696.58'), 4, 'Ukraine'),
#  (Decimal('323.24'), 4, 'United Arab Emirates'),
#  (Decimal('760.20'), 4, 'United Kingdom'),
#  (Decimal('3324.40'), 4, 'United States'),
#  (Decimal('584.54'), 4, 'Venezuela'),
#  (Decimal('616.62'), 4, 'Vietnam'),
#  (Decimal('137.64'), 4, 'Virgin Islands, U.S.'),
#  (Decimal('524.86'), 4, 'Yemen'),
#  (Decimal('257.46'), 4, 'Yugoslavia'),
#  (Decimal('109.72'), 4, 'Zambia'),
#  (Decimal('11.96'), 5, 'Algeria'),
#  (Decimal('53.82'), 5, 'Argentina'),
#  (Decimal('5.98'), 5, 'Armenia'),
#  (Decimal('1.98'), 5, 'Azerbaijan'),
#  (Decimal('5.98'), 5, 'Bahrain'),
#  (Decimal('5.98'), 5, 'Bangladesh'),
#  (Decimal('5.98'), 5, 'Belarus'),
#  (Decimal('5.98'), 5, 'Bolivia'),
#  (Decimal('45.86'), 5, 'Brazil'),
#  (Decimal('9.98'), 5, 'Brunei'),
#  (Decimal('1.98'), 5, 'Bulgaria'),
#  (Decimal('19.92'), 5, 'Cambodia'),
#  (Decimal('13.94'), 5, 'Cameroon'),
#  (Decimal('7.96'), 5, 'Canada'),
#  (Decimal('81.74'), 5, 'China'),
#  (Decimal('29.94'), 5, 'Colombia'),
#  (Decimal('1.98'), 5, 'Faroe Islands'),
#  (Decimal('1.98'), 5, 'France'),
#  (Decimal('17.94'), 5, 'French Polynesia'),
#  (Decimal('29.90'), 5, 'Germany'),
#  (Decimal('1.98'), 5, 'Greece'),
#  (Decimal('1.98'), 5, 'Hungary'),
#  (Decimal('125.54'), 5, 'India'),
#  (Decimal('11.96'), 5, 'Indonesia'),
#  (Decimal('9.98'), 5, 'Iran'),
#  (Decimal('1.98'), 5, 'Iraq'),
#  (Decimal('5.98'), 5, 'Israel'),
#  (Decimal('7.96'), 5, 'Italy'),
#  (Decimal('45.82'), 5, 'Japan'),
#  (Decimal('5.98'), 5, 'Kenya'),
#  (Decimal('1.98'), 5, 'Kuwait'),
#  (Decimal('5.98'), 5, 'Latvia'),
#  (Decimal('9.98'), 5, 'Lithuania'),
#  (Decimal('1.98'), 5, 'Malaysia'),
#  (Decimal('27.88'), 5, 'Mexico'),
#  (Decimal('9.98'), 5, 'Morocco'),
#  (Decimal('1.98'), 5, 'Netherlands'),
#  (Decimal('17.94'), 5, 'Nigeria'),
#  (Decimal('9.98'), 5, 'Oman'),
#  (Decimal('9.98'), 5, 'Peru'),
#  (Decimal('51.80'), 5, 'Philippines'),
#  (Decimal('1.98'), 5, 'Puerto Rico'),
#  (Decimal('15.92'), 5, 'Russian Federation'),
#  (Decimal('7.96'), 5, 'Saudi Arabia'),
#  (Decimal('9.98'), 5, 'South Africa'),
#  (Decimal('7.96'), 5, 'South Korea'),
#  (Decimal('19.96'), 5, 'Spain'),
#  (Decimal('15.96'), 5, 'Switzerland'),
#  (Decimal('37.86'), 5, 'Taiwan'),
#  (Decimal('9.98'), 5, 'Tanzania'),
#  (Decimal('11.96'), 5, 'Thailand'),
#  (Decimal('1.98'), 5, 'Tunisia'),
#  (Decimal('21.94'), 5, 'Turkey'),
#  (Decimal('5.98'), 5, 'Turkmenistan'),
#  (Decimal('9.98'), 5, 'United Arab Emirates'),
#  (Decimal('23.92'), 5, 'United Kingdom'),
#  (Decimal('57.78'), 5, 'United States'),
#  (Decimal('11.96'), 5, 'Venezuela'),
#  (Decimal('17.94'), 5, 'Vietnam'),
#  (Decimal('5.98'), 5, 'Yemen'),
#  (Decimal('1.98'), 5, 'Zambia')]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>month</th>
#         <th>country</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Australia</td>
#         <td>2364.19</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Canada</td>
#         <td>2460.24</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Australia</td>
#         <td>4895.10</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Canada</td>
#         <td>4736.78</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Australia</td>
#         <td>12060.33</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## Revenue Total, by Month, by Country, by Month & Country All in one shot
#
# TODO: Write a query that calculates total revenue at the various grouping levels done above (total, by month, by country, by month & country) all at once using the grouping sets function. Your output should match the table below.

# %%
# %%sql
# SELECT sum(sales_amount) as revenue, dd.month, dc.country
# FROM factSales fs
#     JOIN dimDate dd ON(fs.data_key = dd.date_key)
#     JOIN dimCustomer dc ON(fs.customer_key = dc.customer_key)
# GROUP BY grouping sets ((), dd.month, dc.country, (dd.month, dc.country))
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 598 rows affected.
# [(Decimal('67.84'), 1, 'Algeria'),
#  (Decimal('55.86'), 1, 'Angola'),
#  (Decimal('13.94'), 1, 'Anguilla'),
#  (Decimal('163.56'), 1, 'Argentina'),
#  (Decimal('45.84'), 1, 'Austria'),
#  (Decimal('41.94'), 1, 'Azerbaijan'),
#  (Decimal('7.98'), 1, 'Bahrain'),
#  (Decimal('39.90'), 1, 'Bangladesh'),
#  (Decimal('11.96'), 1, 'Belarus'),
#  (Decimal('9.94'), 1, 'Bolivia'),
#  (Decimal('421.00'), 1, 'Brazil'),
#  (Decimal('11.98'), 1, 'Brunei'),
#  (Decimal('19.96'), 1, 'Bulgaria'),
#  (Decimal('23.92'), 1, 'Cambodia'),
#  (Decimal('27.94'), 1, 'Cameroon'),
#  (Decimal('67.86'), 1, 'Canada'),
#  (Decimal('25.92'), 1, 'Chad'),
#  (Decimal('49.90'), 1, 'Chile'),
#  (Decimal('911.82'), 1, 'China'),
#  (Decimal('95.74'), 1, 'Colombia'),
#  (Decimal('87.84'), 1, 'Congo, The Democratic Republic of the'),
#  (Decimal('1.98'), 1, 'Czech Republic'),
#  (Decimal('27.94'), 1, 'Dominican Republic'),
#  (Decimal('41.90'), 1, 'Ecuador'),
#  (Decimal('69.82'), 1, 'Egypt'),
#  (Decimal('19.96'), 1, 'Estonia'),
#  (Decimal('13.98'), 1, 'Faroe Islands'),
#  (Decimal('7.98'), 1, 'Finland'),
#  (Decimal('79.84'), 1, 'France'),
#  (Decimal('11.96'), 1, 'French Guiana'),
#  (Decimal('59.88'), 1, 'French Polynesia'),
#  (Decimal('29.94'), 1, 'Gambia'),
#  (Decimal('179.60'), 1, 'Germany'),
#  (Decimal('55.84'), 1, 'Greece'),
#  (Decimal('35.88'), 1, 'Greenland'),
#  (Decimal('11.96'), 1, 'Holy See (Vatican City State)'),
#  (Decimal('859.78'), 1, 'India'),
#  (Decimal('271.38'), 1, 'Indonesia'),
#  (Decimal('111.68'), 1, 'Iran'),
#  (Decimal('79.78'), 1, 'Israel'),
#  (Decimal('103.78'), 1, 'Italy'),
#  (Decimal('576.70'), 1, 'Japan'),
#  (Decimal('11.94'), 1, 'Kazakstan'),
#  (Decimal('15.94'), 1, 'Kenya'),
#  (Decimal('9.98'), 1, 'Kuwait'),
#  (Decimal('25.94'), 1, 'Latvia'),
#  (Decimal('29.96'), 1, 'Liechtenstein'),
#  (Decimal('19.96'), 1, 'Lithuania'),
#  (Decimal('1.98'), 1, 'Madagascar'),
#  (Decimal('3.98'), 1, 'Malawi'),
#  (Decimal('61.88'), 1, 'Malaysia'),
#  (Decimal('526.74'), 1, 'Mexico'),
#  (Decimal('65.88'), 1, 'Morocco'),
#  (Decimal('57.90'), 1, 'Mozambique'),
#  (Decimal('29.90'), 1, 'Myanmar'),
#  (Decimal('9.98'), 1, 'Nauru'),
#  (Decimal('31.94'), 1, 'Nepal'),
#  (Decimal('51.88'), 1, 'Netherlands'),
#  (Decimal('13.98'), 1, 'New Zealand'),
#  (Decimal('269.42'), 1, 'Nigeria'),
#  (Decimal('11.96'), 1, 'North Korea'),
#  (Decimal('51.88'), 1, 'Oman'),
#  (Decimal('103.76'), 1, 'Pakistan'),
#  (Decimal('3.96'), 1, 'Paraguay'),
#  (Decimal('81.82'), 1, 'Peru'),
#  (Decimal('323.24'), 1, 'Philippines'),
#  (Decimal('109.78'), 1, 'Poland'),
#  (Decimal('31.90'), 1, 'Puerto Rico'),
#  (Decimal('33.92'), 1, 'Romania'),
#  (Decimal('9.98'), 1, 'Runion'),
#  (Decimal('450.80'), 1, 'Russian Federation'),
#  (Decimal('31.94'), 1, 'Saint Vincent and the Grenadines'),
#  (Decimal('131.74'), 1, 'Saudi Arabia'),
#  (Decimal('9.98'), 1, 'Senegal'),
#  (Decimal('17.94'), 1, 'Slovakia'),
#  (Decimal('199.52'), 1, 'South Africa'),
#  (Decimal('93.76'), 1, 'South Korea'),
#  (Decimal('113.70'), 1, 'Spain'),
#  (Decimal('25.94'), 1, 'Sri Lanka'),
#  (Decimal('49.90'), 1, 'Sudan'),
#  (Decimal('9.98'), 1, 'Sweden'),
#  (Decimal('7.96'), 1, 'Switzerland'),
#  (Decimal('111.68'), 1, 'Taiwan'),
#  (Decimal('37.90'), 1, 'Tanzania'),
#  (Decimal('35.92'), 1, 'Thailand'),
#  (Decimal('17.96'), 1, 'Tonga'),
#  (Decimal('241.46'), 1, 'Turkey'),
#  (Decimal('19.98'), 1, 'Turkmenistan'),
#  (Decimal('53.92'), 1, 'Tuvalu'),
#  (Decimal('109.78'), 1, 'Ukraine'),
#  (Decimal('25.90'), 1, 'United Arab Emirates'),
#  (Decimal('147.68'), 1, 'United Kingdom'),
#  (Decimal('618.60'), 1, 'United States'),
#  (Decimal('49.84'), 1, 'Venezuela'),
#  (Decimal('67.82'), 1, 'Vietnam'),
#  (Decimal('1.98'), 1, 'Virgin Islands, U.S.'),
#  (Decimal('31.88'), 1, 'Yemen'),
#  (Decimal('51.88'), 1, 'Yugoslavia'),
#  (Decimal('25.94'), 1, 'Zambia'),
#  (Decimal('9648.86'), 1, None),
#  (Decimal('9.94'), 2, 'Afghanistan'),
#  (Decimal('121.76'), 2, 'Algeria'),
#  (Decimal('47.90'), 2, 'American Samoa'),
#  (Decimal('71.84'), 2, 'Angola'),
#  (Decimal('33.90'), 2, 'Anguilla'),
#  (Decimal('438.98'), 2, 'Argentina'),
#  (Decimal('25.96'), 2, 'Armenia'),
#  (Decimal('79.78'), 2, 'Austria'),
#  (Decimal('51.86'), 2, 'Azerbaijan'),
#  (Decimal('61.90'), 2, 'Bahrain'),
#  (Decimal('121.72'), 2, 'Bangladesh'),
#  (Decimal('61.80'), 2, 'Belarus'),
#  (Decimal('87.78'), 2, 'Bolivia'),
#  (Decimal('909.74'), 2, 'Brazil'),
#  (Decimal('25.92'), 2, 'Brunei'),
#  (Decimal('85.78'), 2, 'Bulgaria'),
#  (Decimal('73.80'), 2, 'Cambodia'),
#  (Decimal('67.82'), 2, 'Cameroon'),
#  (Decimal('151.60'), 2, 'Canada'),
#  (Decimal('19.96'), 2, 'Chad'),
#  (Decimal('103.74'), 2, 'Chile'),
#  (Decimal('1678.04'), 2, 'China'),
#  (Decimal('145.66'), 2, 'Colombia'),
#  (Decimal('57.82'), 2, 'Congo, The Democratic Republic of the'),
#  (Decimal('31.94'), 2, 'Czech Republic'),
#  (Decimal('67.82'), 2, 'Dominican Republic'),
#  (Decimal('109.80'), 2, 'Ecuador'),
#  (Decimal('243.46'), 2, 'Egypt'),
#  (Decimal('51.88'), 2, 'Estonia'),
#  (Decimal('35.92'), 2, 'Ethiopia'),
#  (Decimal('21.94'), 2, 'Faroe Islands'),
#  (Decimal('37.92'), 2, 'Finland'),
#  (Decimal('105.64'), 2, 'France'),
#  (Decimal('25.96'), 2, 'French Guiana'),
#  (Decimal('37.90'), 2, 'French Polynesia'),
#  (Decimal('21.96'), 2, 'Gambia'),
#  (Decimal('267.42'), 2, 'Germany'),
#  (Decimal('59.88'), 2, 'Greece'),
#  (Decimal('7.98'), 2, 'Greenland'),
#  (Decimal('83.86'), 2, 'Holy See (Vatican City State)'),
#  (Decimal('75.88'), 2, 'Hong Kong'),
#  (Decimal('49.90'), 2, 'Hungary'),
#  (Decimal('1665.84'), 2, 'India'),
#  (Decimal('478.84'), 2, 'Indonesia'),
#  (Decimal('259.30'), 2, 'Iran'),
#  (Decimal('25.94'), 2, 'Iraq'),
#  (Decimal('107.78'), 2, 'Israel'),
#  (Decimal('243.52'), 2, 'Italy'),
#  (Decimal('977.66'), 2, 'Japan'),
#  (Decimal('67.80'), 2, 'Kazakstan'),
#  (Decimal('117.78'), 2, 'Kenya'),
#  (Decimal('73.84'), 2, 'Kuwait'),
#  (Decimal('97.80'), 2, 'Latvia'),
#  (Decimal('41.90'), 2, 'Liechtenstein'),
#  (Decimal('23.94'), 2, 'Lithuania'),
#  (Decimal('25.94'), 2, 'Madagascar'),
#  (Decimal('27.92'), 2, 'Malawi'),
#  (Decimal('95.76'), 2, 'Malaysia'),
#  (Decimal('1009.66'), 2, 'Mexico'),
#  (Decimal('31.90'), 2, 'Moldova'),
#  (Decimal('83.80'), 2, 'Morocco'),
#  (Decimal('29.90'), 2, 'Mozambique'),
#  (Decimal('95.74'), 2, 'Myanmar'),
#  (Decimal('25.94'), 2, 'Nauru'),
#  (Decimal('13.96'), 2, 'Nepal'),
#  (Decimal('173.66'), 2, 'Netherlands'),
#  (Decimal('27.94'), 2, 'New Zealand'),
#  (Decimal('355.20'), 2, 'Nigeria'),
#  (Decimal('1.98'), 2, 'North Korea'),
#  (Decimal('65.84'), 2, 'Oman'),
#  (Decimal('163.62'), 2, 'Pakistan'),
#  (Decimal('69.80'), 2, 'Paraguay'),
#  (Decimal('143.66'), 2, 'Peru'),
#  (Decimal('718.34'), 2, 'Philippines'),
#  (Decimal('323.32'), 2, 'Poland'),
#  (Decimal('65.84'), 2, 'Puerto Rico'),
#  (Decimal('53.84'), 2, 'Romania'),
#  (Decimal('45.90'), 2, 'Runion'),
#  (Decimal('851.88'), 2, 'Russian Federation'),
#  (Decimal('31.92'), 2, 'Saint Vincent and the Grenadines'),
#  (Decimal('75.82'), 2, 'Saudi Arabia'),
#  (Decimal('51.86'), 2, 'Senegal'),
#  (Decimal('33.92'), 2, 'Slovakia'),
#  (Decimal('355.16'), 2, 'South Africa'),
#  (Decimal('109.68'), 2, 'South Korea'),
#  (Decimal('137.70'), 2, 'Spain'),
#  (Decimal('21.94'), 2, 'Sri Lanka'),
#  (Decimal('55.80'), 2, 'Sudan'),
#  (Decimal('59.86'), 2, 'Sweden'),
#  (Decimal('61.88'), 2, 'Switzerland'),
#  (Decimal('343.20'), 2, 'Taiwan'),
#  (Decimal('69.80'), 2, 'Tanzania'),
#  (Decimal('127.68'), 2, 'Thailand'),
#  (Decimal('19.94'), 2, 'Tonga'),
#  (Decimal('9.98'), 2, 'Tunisia'),
#  (Decimal('412.96'), 2, 'Turkey'),
#  (Decimal('63.86'), 2, 'Turkmenistan'),
#  (Decimal('23.94'), 2, 'Tuvalu'),
#  (Decimal('159.60'), 2, 'Ukraine'),
#  (Decimal('127.66'), 2, 'United Arab Emirates'),
#  (Decimal('365.24'), 2, 'United Kingdom'),
#  (Decimal('1180.96'), 2, 'United States'),
#  (Decimal('281.36'), 2, 'Venezuela'),
#  (Decimal('233.48'), 2, 'Vietnam'),
#  (Decimal('53.86'), 2, 'Virgin Islands, U.S.'),
#  (Decimal('141.64'), 2, 'Yemen'),
#  (Decimal('61.84'), 2, 'Yugoslavia'),
#  (Decimal('35.88'), 2, 'Zambia'),
#  (Decimal('19263.76'), 2, None),
#  (Decimal('49.86'), 3, 'Afghanistan'),
#  (Decimal('223.44'), 3, 'Algeria'),
#  (Decimal('15.92'), 3, 'American Samoa'),
#  (Decimal('135.66'), 3, 'Angola'),
#  (Decimal('89.74'), 3, 'Anguilla'),
#  (Decimal('911.80'), 3, 'Argentina'),
#  (Decimal('63.86'), 3, 'Armenia'),
#  (Decimal('253.40'), 3, 'Austria'),
#  (Decimal('175.58'), 3, 'Azerbaijan'),
#  (Decimal('35.92'), 3, 'Bahrain'),
#  (Decimal('309.28'), 3, 'Bangladesh'),
#  (Decimal('233.48'), 3, 'Belarus'),
#  (Decimal('135.64'), 3, 'Bolivia'),
#  (Decimal('2212.86'), 3, 'Brazil'),
#  (Decimal('59.80'), 3, 'Brunei'),
#  (Decimal('157.60'), 3, 'Bulgaria'),
#  (Decimal('61.78'), 3, 'Cambodia'),
#  (Decimal('143.60'), 3, 'Cameroon'),
#  (Decimal('518.96'), 3, 'Canada'),
#  (Decimal('127.70'), 3, 'Chad'),
#  (Decimal('299.40'), 3, 'Chile'),
#  (Decimal('4123.88'), 3, 'China'),
#  (Decimal('504.92'), 3, 'Colombia'),
#  (Decimal('189.54'), 3, 'Congo, The Democratic Republic of the'),
#  (Decimal('91.82'), 3, 'Czech Republic'),
#  (Decimal('269.30'), 3, 'Dominican Republic'),
#  (Decimal('295.34'), 3, 'Ecuador'),
#  (Decimal('512.80'), 3, 'Egypt'),
#  (Decimal('103.72'), 3, 'Estonia'),
#  (Decimal('99.78'), 3, 'Ethiopia'),
#  (Decimal('89.78'), 3, 'Faroe Islands'),
#  (Decimal('91.78'), 3, 'Finland'),
#  (Decimal('161.52'), 3, 'France'),
#  (Decimal('93.82'), 3, 'French Guiana'),
#  (Decimal('183.62'), 3, 'French Polynesia'),
#  (Decimal('117.74'), 3, 'Gambia'),
#  (Decimal('532.74'), 3, 'Germany'),
#  (Decimal('165.60'), 3, 'Greece'),
#  (Decimal('113.76'), 3, 'Greenland'),
#  (Decimal('115.76'), 3, 'Holy See (Vatican City State)'),
#  (Decimal('109.76'), 3, 'Hong Kong'),
#  (Decimal('47.84'), 3, 'Hungary'),
#  (Decimal('5094.46'), 3, 'India'),
#  (Decimal('1045.26'), 3, 'Indonesia'),
#  (Decimal('700.44'), 3, 'Iran'),
#  (Decimal('63.82'), 3, 'Iraq'),
#  (Decimal('243.40'), 3, 'Israel'),
#  (Decimal('628.52'), 3, 'Italy'),
#  (Decimal('2506.06'), 3, 'Japan'),
#  (Decimal('123.70'), 3, 'Kazakstan'),
#  (Decimal('171.64'), 3, 'Kenya'),
#  (Decimal('107.74'), 3, 'Kuwait'),
#  (Decimal('141.68'), 3, 'Latvia'),
#  (Decimal('57.88'), 3, 'Liechtenstein'),
#  (Decimal('39.84'), 3, 'Lithuania'),
#  (Decimal('111.76'), 3, 'Madagascar'),
#  (Decimal('101.80'), 3, 'Malawi'),
#  (Decimal('311.34'), 3, 'Malaysia'),
#  (Decimal('2276.22'), 3, 'Mexico'),
#  (Decimal('91.78'), 3, 'Moldova'),
#  (Decimal('253.44'), 3, 'Morocco'),
#  (Decimal('209.48'), 3, 'Mozambique'),
#  (Decimal('193.54'), 3, 'Myanmar'),
#  (Decimal('139.72'), 3, 'Nauru'),
#  (Decimal('85.86'), 3, 'Nepal'),
#  (Decimal('472.92'), 3, 'Netherlands'),
#  (Decimal('71.84'), 3, 'New Zealand'),
#  (Decimal('1085.54'), 3, 'Nigeria'),
#  (Decimal('97.80'), 3, 'North Korea'),
#  (Decimal('85.78'), 3, 'Oman'),
#  (Decimal('417.00'), 3, 'Pakistan'),
#  (Decimal('183.56'), 3, 'Paraguay'),
#  (Decimal('347.22'), 3, 'Peru'),
#  (Decimal('1811.96'), 3, 'Philippines'),
#  (Decimal('544.60'), 3, 'Poland'),
#  (Decimal('139.70'), 3, 'Puerto Rico'),
#  (Decimal('143.62'), 3, 'Romania'),
#  (Decimal('175.64'), 3, 'Runion'),
#  (Decimal('1919.36'), 3, 'Russian Federation'),
#  (Decimal('35.88'), 3, 'Saint Vincent and the Grenadines'),
#  (Decimal('359.08'), 3, 'Saudi Arabia'),
#  (Decimal('89.80'), 3, 'Senegal'),
#  (Decimal('41.86'), 3, 'Slovakia'),
#  (Decimal('907.96'), 3, 'South Africa'),
#  (Decimal('355.28'), 3, 'South Korea'),
#  (Decimal('426.98'), 3, 'Spain'),
#  (Decimal('93.76'), 3, 'Sri Lanka'),
#  (Decimal('137.70'), 3, 'Sudan'),
#  (Decimal('97.74'), 3, 'Sweden'),
#  (Decimal('137.62'), 3, 'Switzerland'),
#  (Decimal('797.88'), 3, 'Taiwan'),
#  (Decimal('273.30'), 3, 'Tanzania'),
#  (Decimal('295.36'), 3, 'Thailand'),
#  (Decimal('51.86'), 3, 'Tonga'),
#  (Decimal('33.88'), 3, 'Tunisia'),
#  (Decimal('1163.34'), 3, 'Turkey'),
#  (Decimal('107.84'), 3, 'Turkmenistan'),
#  (Decimal('65.82'), 3, 'Tuvalu'),
#  (Decimal('494.88'), 3, 'Ukraine'),
#  (Decimal('179.54'), 3, 'United Arab Emirates'),
#  (Decimal('552.56'), 3, 'United Kingdom'),
#  (Decimal('3038.90'), 3, 'United States'),
#  (Decimal('438.90'), 3, 'Venezuela'),
#  (Decimal('556.70'), 3, 'Vietnam'),
#  (Decimal('51.88'), 3, 'Virgin Islands, U.S.'),
#  (Decimal('317.30'), 3, 'Yemen'),
#  (Decimal('147.68'), 3, 'Yugoslavia'),
#  (Decimal('95.82'), 3, 'Zambia'),
#  (Decimal('47773.12'), 3, None),
#  (Decimal('75.84'), 4, 'Afghanistan'),
#  (Decimal('341.20'), 4, 'Algeria'),
#  (Decimal('79.78'), 4, 'American Samoa'),
#  (Decimal('167.60'), 4, 'Angola'),
#  (Decimal('75.72'), 4, 'Anguilla'),
#  (Decimal('1300.80'), 4, 'Argentina'),
#  (Decimal('141.70'), 4, 'Armenia'),
#  (Decimal('235.42'), 4, 'Austria'),
#  (Decimal('219.50'), 4, 'Azerbaijan'),
#  (Decimal('113.72'), 4, 'Bahrain'),
#  (Decimal('327.22'), 4, 'Bangladesh'),
#  (Decimal('241.46'), 4, 'Belarus'),
#  (Decimal('127.72'), 4, 'Bolivia'),
#  (Decimal('2811.58'), 4, 'Brazil'),
#  (Decimal('119.62'), 4, 'Brunei'),
#  (Decimal('143.68'), 4, 'Bulgaria'),
#  (Decimal('203.52'), 4, 'Cambodia'),
#  (Decimal('147.62'), 4, 'Cameroon'),
#  (Decimal('440.88'), 4, 'Canada'),
#  (Decimal('97.78'), 4, 'Chad'),
#  (Decimal('203.54'), 4, 'Chile'),
#  (Decimal('4809.98'), 4, 'China'),
#  (Decimal('642.56'), 4, 'Colombia'),
#  (Decimal('89.80'), 4, 'Congo, The Democratic Republic of the'),
#  (Decimal('141.68'), 4, 'Czech Republic'),
#  (Decimal('271.40'), 4, 'Dominican Republic'),
#  (Decimal('333.22'), 4, 'Ecuador'),
#  (Decimal('562.70'), 4, 'Egypt'),
#  (Decimal('55.84'), 4, 'Estonia'),
#  (Decimal('47.84'), 4, 'Ethiopia'),
#  (Decimal('101.76'), 4, 'Faroe Islands'),
#  (Decimal('65.80'), 4, 'Finland'),
#  (Decimal('399.10'), 4, 'France'),
#  (Decimal('75.82'), 4, 'French Guiana'),
#  (Decimal('171.58'), 4, 'French Polynesia'),
#  (Decimal('89.76'), 4, 'Gambia'),
#  (Decimal('652.42'), 4, 'Germany'),
#  (Decimal('181.62'), 4, 'Greece'),
#  (Decimal('117.70'), 4, 'Greenland'),
#  (Decimal('93.74'), 4, 'Holy See (Vatican City State)'),
#  (Decimal('99.76'), 4, 'Hong Kong'),
#  (Decimal('123.70'), 4, 'Hungary'),
#  (Decimal('5514.92'), 4, 'India'),
#  (Decimal('1213.22'), 4, 'Indonesia'),
#  (Decimal('820.10'), 4, 'Iran'),
#  (Decimal('131.72'), 4, 'Iraq'),
#  (Decimal('407.08'), 4, 'Israel'),
#  (Decimal('678.44'), 4, 'Italy'),
#  (Decimal('2837.24'), 4, 'Japan'),
#  (Decimal('193.52'), 4, 'Kazakstan'),
#  (Decimal('195.58'), 4, 'Kenya'),
#  (Decimal('29.94'), 4, 'Kuwait'),
#  (Decimal('253.40'), 4, 'Latvia'),
#  (Decimal('99.70'), 4, 'Liechtenstein'),
#  (Decimal('53.80'), 4, 'Lithuania'),
#  (Decimal('47.88'), 4, 'Madagascar'),
#  (Decimal('113.74'), 4, 'Malawi'),
#  (Decimal('267.34'), 4, 'Malaysia'),
#  (Decimal('2773.58'), 4, 'Mexico'),
#  (Decimal('131.64'), 4, 'Moldova'),
#  (Decimal('201.48'), 4, 'Morocco'),
#  (Decimal('391.12'), 4, 'Mozambique'),
#  (Decimal('69.78'), 4, 'Myanmar'),
#  (Decimal('121.74'), 4, 'Nauru'),
#  (Decimal('101.80'), 4, 'Nepal'),
#  (Decimal('472.88'), 4, 'Netherlands'),
#  (Decimal('71.76'), 4, 'New Zealand'),
#  (Decimal('1294.86'), 4, 'Nigeria'),
#  (Decimal('115.64'), 4, 'North Korea'),
#  (Decimal('161.52'), 4, 'Oman'),
#  (Decimal('367.06'), 4, 'Pakistan'),
#  (Decimal('293.44'), 4, 'Paraguay'),
#  (Decimal('355.08'), 4, 'Peru'),
#  (Decimal('1857.30'), 4, 'Philippines'),
#  (Decimal('778.24'), 4, 'Poland'),
#  (Decimal('269.36'), 4, 'Puerto Rico'),
#  (Decimal('239.38'), 4, 'Romania'),
#  (Decimal('201.56'), 4, 'Runion'),
#  (Decimal('2853.78'), 4, 'Russian Federation'),
#  (Decimal('93.76'), 4, 'Saint Vincent and the Grenadines'),
#  (Decimal('472.98'), 4, 'Saudi Arabia'),
#  (Decimal('49.86'), 4, 'Senegal'),
#  (Decimal('85.76'), 4, 'Slovakia'),
#  (Decimal('935.68'), 4, 'South Africa'),
#  (Decimal('582.62'), 4, 'South Korea'),
#  (Decimal('514.82'), 4, 'Spain'),
#  (Decimal('91.76'), 4, 'Sri Lanka'),
#  (Decimal('211.52'), 4, 'Sudan'),
#  (Decimal('121.74'), 4, 'Sweden'),
#  (Decimal('281.36'), 4, 'Switzerland'),
#  (Decimal('1131.26'), 4, 'Taiwan'),
#  (Decimal('291.36'), 4, 'Tanzania'),
#  (Decimal('367.16'), 4, 'Thailand'),
#  (Decimal('57.88'), 4, 'Tonga'),
#  (Decimal('111.70'), 4, 'Tunisia'),
#  (Decimal('1484.54'), 4, 'Turkey'),
#  (Decimal('75.80'), 4, 'Turkmenistan'),
#  (Decimal('97.80'), 4, 'Tuvalu'),
#  (Decimal('696.58'), 4, 'Ukraine'),
#  (Decimal('323.24'), 4, 'United Arab Emirates'),
#  (Decimal('760.20'), 4, 'United Kingdom'),
#  (Decimal('3324.40'), 4, 'United States'),
#  (Decimal('584.54'), 4, 'Venezuela'),
#  (Decimal('616.62'), 4, 'Vietnam'),
#  (Decimal('137.64'), 4, 'Virgin Islands, U.S.'),
#  (Decimal('524.86'), 4, 'Yemen'),
#  (Decimal('257.46'), 4, 'Yugoslavia'),
#  (Decimal('109.72'), 4, 'Zambia'),
#  (Decimal('57118.92'), 4, None),
#  (Decimal('11.96'), 5, 'Algeria'),
#  (Decimal('53.82'), 5, 'Argentina'),
#  (Decimal('5.98'), 5, 'Armenia'),
#  (Decimal('1.98'), 5, 'Azerbaijan'),
#  (Decimal('5.98'), 5, 'Bahrain'),
#  (Decimal('5.98'), 5, 'Bangladesh'),
#  (Decimal('5.98'), 5, 'Belarus'),
#  (Decimal('5.98'), 5, 'Bolivia'),
#  (Decimal('45.86'), 5, 'Brazil'),
#  (Decimal('9.98'), 5, 'Brunei'),
#  (Decimal('1.98'), 5, 'Bulgaria'),
#  (Decimal('19.92'), 5, 'Cambodia'),
#  (Decimal('13.94'), 5, 'Cameroon'),
#  (Decimal('7.96'), 5, 'Canada'),
#  (Decimal('81.74'), 5, 'China'),
#  (Decimal('29.94'), 5, 'Colombia'),
#  (Decimal('1.98'), 5, 'Faroe Islands'),
#  (Decimal('1.98'), 5, 'France'),
#  (Decimal('17.94'), 5, 'French Polynesia'),
#  (Decimal('29.90'), 5, 'Germany'),
#  (Decimal('1.98'), 5, 'Greece'),
#  (Decimal('1.98'), 5, 'Hungary'),
#  (Decimal('125.54'), 5, 'India'),
#  (Decimal('11.96'), 5, 'Indonesia'),
#  (Decimal('9.98'), 5, 'Iran'),
#  (Decimal('1.98'), 5, 'Iraq'),
#  (Decimal('5.98'), 5, 'Israel'),
#  (Decimal('7.96'), 5, 'Italy'),
#  (Decimal('45.82'), 5, 'Japan'),
#  (Decimal('5.98'), 5, 'Kenya'),
#  (Decimal('1.98'), 5, 'Kuwait'),
#  (Decimal('5.98'), 5, 'Latvia'),
#  (Decimal('9.98'), 5, 'Lithuania'),
#  (Decimal('1.98'), 5, 'Malaysia'),
#  (Decimal('27.88'), 5, 'Mexico'),
#  (Decimal('9.98'), 5, 'Morocco'),
#  (Decimal('1.98'), 5, 'Netherlands'),
#  (Decimal('17.94'), 5, 'Nigeria'),
#  (Decimal('9.98'), 5, 'Oman'),
#  (Decimal('9.98'), 5, 'Peru'),
#  (Decimal('51.80'), 5, 'Philippines'),
#  (Decimal('1.98'), 5, 'Puerto Rico'),
#  (Decimal('15.92'), 5, 'Russian Federation'),
#  (Decimal('7.96'), 5, 'Saudi Arabia'),
#  (Decimal('9.98'), 5, 'South Africa'),
#  (Decimal('7.96'), 5, 'South Korea'),
#  (Decimal('19.96'), 5, 'Spain'),
#  (Decimal('15.96'), 5, 'Switzerland'),
#  (Decimal('37.86'), 5, 'Taiwan'),
#  (Decimal('9.98'), 5, 'Tanzania'),
#  (Decimal('11.96'), 5, 'Thailand'),
#  (Decimal('1.98'), 5, 'Tunisia'),
#  (Decimal('21.94'), 5, 'Turkey'),
#  (Decimal('5.98'), 5, 'Turkmenistan'),
#  (Decimal('9.98'), 5, 'United Arab Emirates'),
#  (Decimal('23.92'), 5, 'United Kingdom'),
#  (Decimal('57.78'), 5, 'United States'),
#  (Decimal('11.96'), 5, 'Venezuela'),
#  (Decimal('17.94'), 5, 'Vietnam'),
#  (Decimal('5.98'), 5, 'Yemen'),
#  (Decimal('1.98'), 5, 'Zambia'),
#  (Decimal('1028.36'), 5, None),
#  (Decimal('134833.02'), None, None),
#  (Decimal('135.64'), None, 'Afghanistan'),
#  (Decimal('766.20'), None, 'Algeria'),
#  (Decimal('143.60'), None, 'American Samoa'),
#  (Decimal('430.96'), None, 'Angola'),
#  (Decimal('213.30'), None, 'Anguilla'),
#  (Decimal('2868.96'), None, 'Argentina'),
#  (Decimal('237.50'), None, 'Armenia'),
#  (Decimal('614.44'), None, 'Austria'),
#  (Decimal('490.86'), None, 'Azerbaijan'),
#  (Decimal('225.50'), None, 'Bahrain'),
#  (Decimal('804.10'), None, 'Bangladesh'),
#  (Decimal('554.68'), None, 'Belarus'),
#  (Decimal('367.06'), None, 'Bolivia'),
#  (Decimal('6401.04'), None, 'Brazil'),
#  (Decimal('227.30'), None, 'Brunei'),
#  (Decimal('409.00'), None, 'Bulgaria'),
#  (Decimal('382.94'), None, 'Cambodia'),
#  (Decimal('400.92'), None, 'Cameroon'),
#  (Decimal('1187.26'), None, 'Canada'),
#  (Decimal('271.36'), None, 'Chad'),
#  (Decimal('656.58'), None, 'Chile'),
#  (Decimal('11605.46'), None, 'China'),
#  (Decimal('1418.82'), None, 'Colombia'),
#  (Decimal('425.00'), None, 'Congo, The Democratic Republic of the'),
#  (Decimal('267.42'), None, 'Czech Republic'),
#  (Decimal('636.46'), None, 'Dominican Republic'),
#  (Decimal('780.26'), None, 'Ecuador'),
#  (Decimal('1388.78'), None, 'Egypt'),
#  (Decimal('231.40'), None, 'Estonia'),
#  (Decimal('183.54'), None, 'Ethiopia'),
#  (Decimal('229.44'), None, 'Faroe Islands'),
#  (Decimal('203.48'), None, 'Finland'),
#  (Decimal('748.08'), None, 'France'),
#  (Decimal('207.56'), None, 'French Guiana'),
#  (Decimal('470.92'), None, 'French Polynesia'),
#  (Decimal('259.40'), None, 'Gambia'),
#  (Decimal('1662.08'), None, 'Germany'),
#  (Decimal('464.92'), None, 'Greece'),
#  (Decimal('275.32'), None, 'Greenland'),
#  (Decimal('305.32'), None, 'Holy See (Vatican City State)'),
#  (Decimal('285.40'), None, 'Hong Kong'),
#  (Decimal('223.42'), None, 'Hungary'),
#  (Decimal('13260.54'), None, 'India'),
#  (Decimal('3020.66'), None, 'Indonesia'),
#  (Decimal('1901.50'), None, 'Iran'),
#  (Decimal('223.46'), None, 'Iraq'),
#  (Decimal('844.02'), None, 'Israel'),
#  (Decimal('1662.22'), None, 'Italy'),
#  (Decimal('6943.48'), None, 'Japan'),
#  (Decimal('396.96'), None, 'Kazakstan'),
#  (Decimal('506.92'), None, 'Kenya'),
#  (Decimal('223.48'), None, 'Kuwait'),
#  (Decimal('524.80'), None, 'Latvia'),
#  (Decimal('229.44'), None, 'Liechtenstein'),
#  (Decimal('147.52'), None, 'Lithuania'),
#  (Decimal('187.56'), None, 'Madagascar'),
#  (Decimal('247.44'), None, 'Malawi'),
#  (Decimal('738.30'), None, 'Malaysia'),
#  (Decimal('6614.08'), None, 'Mexico'),
#  (Decimal('255.32'), None, 'Moldova'),
#  (Decimal('614.58'), None, 'Morocco'),
#  (Decimal('688.40'), None, 'Mozambique'),
#  (Decimal('388.96'), None, 'Myanmar'),
#  (Decimal('297.38'), None, 'Nauru'),
#  (Decimal('233.56'), None, 'Nepal'),
#  (Decimal('1173.32'), None, 'Netherlands'),
#  (Decimal('185.52'), None, 'New Zealand'),
#  (Decimal('3022.96'), None, 'Nigeria'),
#  (Decimal('227.38'), None, 'North Korea'),
#  (Decimal('375.00'), None, 'Oman'),
#  (Decimal('1051.44'), None, 'Pakistan'),
#  (Decimal('550.76'), None, 'Paraguay'),
#  (Decimal('937.76'), None, 'Peru'),
#  (Decimal('4762.64'), None, 'Philippines'),
#  (Decimal('1755.94'), None, 'Poland'),
#  (Decimal('508.78'), None, 'Puerto Rico'),
#  (Decimal('470.76'), None, 'Romania'),
#  (Decimal('433.08'), None, 'Runion'),
#  (Decimal('6091.74'), None, 'Russian Federation'),
#  (Decimal('193.50'), None, 'Saint Vincent and the Grenadines'),
#  (Decimal('1047.58'), None, 'Saudi Arabia'),
#  (Decimal('201.50'), None, 'Senegal'),
#  (Decimal('179.48'), None, 'Slovakia'),
#  (Decimal('2408.30'), None, 'South Africa'),
#  (Decimal('1149.30'), None, 'South Korea'),
#  (Decimal('1213.16'), None, 'Spain'),
#  (Decimal('233.40'), None, 'Sri Lanka'),
#  (Decimal('454.92'), None, 'Sudan'),
#  (Decimal('289.32'), None, 'Sweden'),
#  (Decimal('504.78'), None, 'Switzerland'),
#  (Decimal('2421.88'), None, 'Taiwan'),
#  (Decimal('682.34'), None, 'Tanzania'),
#  (Decimal('838.08'), None, 'Thailand'),
#  (Decimal('147.64'), None, 'Tonga'),
#  (Decimal('157.54'), None, 'Tunisia'),
#  (Decimal('3324.24'), None, 'Turkey'),
#  (Decimal('273.46'), None, 'Turkmenistan'),
#  (Decimal('241.48'), None, 'Tuvalu'),
#  (Decimal('1460.84'), None, 'Ukraine'),
#  (Decimal('666.32'), None, 'United Arab Emirates'),
#  (Decimal('1849.60'), None, 'United Kingdom'),
#  (Decimal('8220.64'), None, 'United States'),
#  (Decimal('1366.60'), None, 'Venezuela'),
#  (Decimal('1492.56'), None, 'Vietnam'),
#  (Decimal('245.36'), None, 'Virgin Islands, U.S.'),
#  (Decimal('1021.66'), None, 'Yemen'),
#  (Decimal('518.86'), None, 'Yugoslavia'),
#  (Decimal('269.34'), None, 'Zambia')]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>month</th>
#         <th>country</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Australia</td>
#         <td>2364.19</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Canada</td>
#         <td>2460.24</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>None</td>
#         <td>4824.43</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Australia</td>
#         <td>4895.10</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Canada</td>
#         <td>4736.78</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>None</td>
#         <td>9631.88</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Australia</td>
#         <td>12060.33</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Canada</td>
#         <td>11826.23</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>None</td>
#         <td>23886.56</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>Australia</td>
#         <td>14136.07</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>Canada</td>
#         <td>14423.39</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>None</td>
#         <td>28559.46</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>Australia</td>
#         <td>271.08</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>Canada</td>
#         <td>243.10</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>None</td>
#         <td>514.18</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>None</td>
#         <td>67416.51</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>Australia</td>
#         <td>33726.77</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>Canada</td>
#         <td>33689.74</td>
#     </tr>
# </tbody></table></div>
